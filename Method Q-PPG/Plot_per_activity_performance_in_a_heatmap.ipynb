# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
data = [[np.nan, np.nan, 16.72, 6.21, 5.79, np.nan, 6.10,np.nan],
        [np.nan, 46.04, 21.15, 53.60, 90.76, 5.33, 2.65, np.nan],
        [np.nan, np.nan, 17.82, 12.87, 9.09, 6.91, 6.62, np.nan],
        [3.45, np.nan, 35, np.nan, np.nan, 38, 39, np.nan],
        [3.51, np.nan, np.nan, 106.70, np.nan, np.nan, np.nan, 4.88],
        [np.nan, np.nan, 61.99, 10.92, np.nan, np.nan, np.nan, np.nan],
        [np.nan, 4.83, 9.30, 4.55, 3.86, 4.84, 4.78, np.nan],
        [np.nan, np.nan, 22.08, np.nan, np.nan, np.nan, 15.93, np.nan],
        [np.nan, 73.19, 36.59, 21.22, np.nan, np.nan, np.nan, np.nan],
        [np.nan, 14.73, 15.32, np.nan, 3.74, np.nan, 4.45, np.nan],
        [3.03, 72.63, 32.93, np.nan, 4.21, np.nan, np.nan, np.nan],
        [np.nan, 28.81, 19.78, 2.54, 6.17, np.nan, 73.29, np.nan],
        [np.nan, np.nan, np.nan, 2.27, 4.92, 5.47, 8.56, np.nan],
        [np.nan, 3.37, 10.26, 4.58, 4.96, 9.47, np.nan, np.nan],
        [np.nan, np.nan, 18.19, np.nan, 6.61, np.nan, 5.69, np.nan]]

# %%
data = [[3.86, 38.88, 17.77, 5.37, 4.31, 6.34, 6.64, 2.64],
        [2.54, 49.35, 25.16, 30.43, 4.28, 3.85, 3.50, 4.17],
        [2.23, 50.22, 16.97, 4.36, 7.03, 8.84, 3.44, 4.84],
        [2.48, 41.44, 15.48, 31.49, 12.33, 9.45, 33.03, 5.39],
        [1.30, 44.29, 75.30, 107.71, 25.89, 7.93, 64.48, 15.41],
        [1.39, 85.98, 65.35, 0.85, 5.29, np.nan, np.nan, np.nan],
        [1.10, 8.28, 5.50, 14.25, 3.20, 3.63, 1.99, 2.76],
        [4.29, 29.91, 23.89, 9.22, 12.90, 8.01, 19.43, 3.04],
        [2.25, 33.13, 26.02, 57.78, 12.00, 11.38, 44.60, 13.56],
        [1.38, 21.42, 22.67, 5.25, 2.26, 1.27, 2.48, 3.14],
        [2.27, 75.33, 34.56, 84.80, 3.53, 9.50, 63.99, 3.32],
        [1.34, 30.61, 16.78, 12.53, 5.31, 8.33, 15.84, 17.09],
        [1.52, 41.92, 16.26, 2.58, 3.31, 4.84, 13.57, 2.37],
        [0.81, 6.07, 12.40, 26.47, 3.16, 8.57, 35.24, 3.82],
        [1.78, 44.88, 21.55, 47.78, 5.82, 4.49, 4.71, 1.80]]

dataa = np.array(data)
moyennes = [np.mean(dataa[:,0]), np.mean(dataa[:,1]), np.mean(dataa[:,2]), np.mean(dataa[:,3]), np.mean(dataa[:,4]), np.nanmean(dataa[:,5]), np.nanmean(dataa[:,6]), np.nanmean(dataa[:,7])]

dataa = np.vstack((dataa, moyennes))

# %%
####### Q PPG #################

data = [[2.02 , 10.42,  8.18,  2.75,  2.59, 3.12,  4.41, 1.98],
        [1.57, 13.47,  4.65,  8.60, 2.90, 2.84,  1.63, 2.01],
        [2.31 , 1.63, 3.56 , 2.13, 3.02, 2.91, 1.54, 2.00],
        [2.80, 12.42,  4.90, 15.30,  3.26, 2.91,  5.75,  2.00],
        [0.86, 63.64,  3.59, 19.09,  1.43, 1.61, 31.37,  1.65],
        [0.70, 15.84,  8.27,  3.28,  2.51, np.nan, np.nan, np.nan],
        [2.01, 9.46, 2.31, 2.05, 1.97, 1.95, 1.92, 1.49],
        [3.40, 22.41, 4.39, 6.63, 5.14, 4.79, 6.28, 2.71],
        [3.13, 13.10, 3.93, 11.29, 6.11, 4.88, 15.82, 7.35],
        [0.75, 13.28, 3.58, 1.69, 1.09, 1.14, 1.80, 1.42],
        [1.57, 15.05, 5.83, 1.35, 2.65, 3.41, 13.23, 1.69],
        [3.64, 11.78, 8.55, 1.89, 2.51, 3.25, 14.00, 2.11],
        [2.42, 1.41, 5.73, 1.36, 1.71, 1.98, 2.75, 1.89],
        [1.05, 1.74, 3.50, 2.27, 2.36, 2.40, 8.40, 2.43],
        [2.05, 12.18, 3.68, 5.80, 2.53, 1.94, 1.95, 2.04]]

dataa = np.array(data)
moyennes = [np.mean(dataa[:,0]), np.mean(dataa[:,1]), np.mean(dataa[:,2]), np.mean(dataa[:,3]), np.mean(dataa[:,4]), np.nanmean(dataa[:,5]), np.nanmean(dataa[:,6]), np.nanmean(dataa[:,7])]

dataa = np.vstack((dataa, moyennes))

# %%
x_labels = ['S1','S2','S3','S4','S5','S6','S7','S8','S9','S10','S11','S12','S13','S14', 'S15', 'moyenne']
y_labels = ['Assis','Escaliers','Babyfoot','Vélo','Conduite','Déjeuner','Marche','Travail']

# %%
df = pd.DataFrame(dataa, index = x_labels, columns = y_labels)

# %%
sns.set(font_scale=0.9)

# %%
annot_df = df.applymap(lambda f: f'{f:.2f}')
fig, ax = plt.subplots(squeeze=False)
sns.heatmap(
    np.where(df.isna(), 0, np.nan),
    ax=ax[0, 0],
    cbar=False,
    annot=np.full_like(df, "--", dtype=object),
    fmt="",
    annot_kws={"size": 10, "va": "center_baseline", "color": "black"},
    cmap=ListedColormap(['whitesmoke']),
    linecolor='white',
    linewidth=0.1)
sns.heatmap(
    df,
    ax=ax[0, 0],
    cbar=True,
    annot=annot_df,    annot_kws={"size": 9, "va": "center_baseline"},

    fmt="",
    cmap = sns.color_palette("ch:start=.2,rot=-.3", as_cmap=True),
    linewidth=0.7,
    linecolor="white",
    xticklabels=True,
    yticklabels=True)
plt.show()

# %%
plt.tight_layout()

# %%
fig.figure.savefig('hm1 (8)', bbox_inches="tight", dpi=150)
